# %% [markdown]
# # Numerička matematika - 11. predavanje

# %% [markdown]
# ## 11.1. Rješavanje nelinearnih jednadžbi (nastavak)

# %% [markdown]
# Prije nego krenemo s Newtonovom metodom ipak ćemo spomenuti najjednostavnije metode koje se primjenjuju u rješavanju nelinearnih jednadžbi. Newtonova metoda koju ćemo danas obraditi poseban je slučaj metode jednostavnih iteracija, a u sljedećem videu možete vidjeti metode do kojih možemo doći korištenjem jenostavnih zaključaka iz Matematike 1!
#
# **Metoda bisekcije**

# %%
from IPython.lib.display import YouTubeVideo
vid = YouTubeVideo("bYFwgPfUuCM")
display(vid)

# %% [markdown]
# Sada nastavljamo tamo gdje smo stali na prethodnom predavanju, budući da je ovo prirodan nastavak na metodu jednostavnih iteracija.

# %% [markdown]
# ## 11.2. Newtonova metoda, metoda sekante i globalno konvergentna Newtonova metoda

# %% [markdown]
# U ovom dijelu predavanja uvodimo metode iz naslova, bez rješavanja zadataka.

# %%
vid = YouTubeVideo("DbeV6Trj_PM") 
display(vid)

# %% [markdown]
# ## 11.3  Vježbe
#
# Sada rješavamo zadatke vezane za nelinearne jednadžbe u jednoj dimenziji

# %%
vid = YouTubeVideo("pfdspg9mH3k") 
display(vid)
